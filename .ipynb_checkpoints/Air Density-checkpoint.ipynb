# %%
# Set up
import os
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sbn
import boto
import boto3
import io
import csv

path = '/Users/sheri/documents/data science/data mining/homework/project 1'

os.listdir(path)
# Out:
# ['.ipynb_checkpoints',
#  'Air Density.ipynb',
#  'FaultCode_DowntimeMapping.xlsx',
#  'ICA1_DataMining.ipynb',
#  'LGW_Down_Turbine_Tracker.xlsx',
#  'Lightning.csv',
#  'Meteorological data writeup.docx',
#  'Meteorological_Notebook_SAL.py',
#  'MetTower (1).ipynb',
#  'MetTower.ipynb',
#  'MetTower_complete.csv',
#  'MetTower_LGW_2017.csv',
#  'PowerCurveData.csv',
#  'PowerCurves.csv',
#  'SCADAcombined2017Q1.csv',
#  'SCADAcombined2017Q1.csv.gz',
#  'SCADAcombined2017Q1.csv.gzip',
#  'SCADAcombined2017Q2.csv',
#  'Siemens Error Code Stop and Reset Details.xlsx',
#  'Siemens_Fault_Code_Descriptions.xlsx',
#  'tblSCTurbine.csv',
#  'WpsHistoryDescription_V_310.pdf']

# %%
df_MT = pd.read_csv(path + '/SCADAcombined2017Q1.csv')
#print(df_MetTower)
df_MT.describe()
# Out:
#           StationId  CommunicationId   NeighbourId  NeighbourIdTwo  \
# count  1.111023e+06     1.111023e+06  1.111023e+06    1.111023e+06
# mean   4.404165e+01     2.309002e+06  4.403962e+01    4.468494e+01
# std    2.511075e+01     2.511075e+01  2.492885e+01    2.469343e+01
# min    1.000000e+00     2.308959e+06  2.000000e+00    1.000000e+00
# 25%    2.200000e+01     2.308980e+06  2.300000e+01    2.400000e+01
# 50%    4.400000e+01     2.309002e+06  4.300000e+01    4.400000e+01
# 75%    6.600000e+01     2.309024e+06  6.500000e+01    6.600000e+01
# max    8.700000e+01     2.309045e+06  8.600000e+01    8.700000e+01
#
#                XPos          YPos  wtc_ActPower_min  wtc_ActPower_max  \
# count  1.111023e+06  1.111023e+06      1.110941e+06      1.110941e+06
# mean   5.349489e+02  7.647548e+02      8.140967e+02      1.453176e+03
# std    3.398955e+02  4.244587e+02      7.543171e+02      8.236300e+02
# min    3.000000e+01  1.500000e+02     -5.100000e+02     -2.900000e+01
# 25%    2.600000e+02  4.500000e+02      1.560000e+02      7.110000e+02
# 50%    4.900000e+02  7.500000e+02      5.870000e+02      1.570000e+03
# 75%    8.350000e+02  1.050000e+03      1.399000e+03      2.324000e+03
# max    1.065000e+03  1.650000e+03      2.382000e+03      2.614000e+03
#
#        wtc_ActPower_mean  wtc_ActPower_stddev      ...       \
# count       1.110941e+06         1.110941e+06      ...
# mean        1.138954e+03         1.456796e+02      ...
# std         7.861914e+02         1.319418e+02      ...
# min        -4.383652e+01         0.000000e+00      ...
# 25%         4.273109e+02         4.366027e+01      ...
# 50%         1.069538e+03         1.034365e+02      ...
# 75%         1.865646e+03         2.149697e+02      ...
# max         2.426992e+03         1.181508e+03      ...
#
#        WindDir_76m_D1_WVT  WindDir_76m_SD1_WVT  WindDir_Angle_3D_Avg.1  \
# count        1.111023e+06         1.111023e+06            1.111023e+06
# mean         1.212786e+02         5.394040e+00            5.700405e+02
# std          9.657042e+01         1.040793e+01            2.700509e+01
# min          2.900000e-02         5.900000e-02            3.070000e+01
# 25%          8.350000e+01         8.220000e-01            5.709000e+02
# 50%          1.044000e+02         1.757000e+00            5.716000e+02
# 75%          1.106000e+02         5.322000e+00            5.719000e+02
# max          3.600000e+02         7.946000e+01            5.781000e+02
#
#        WindDir_Angle_3D_Std.1  Elevation_angle_3D_Avg  WS_ICEFREE_Avg  \
# count            1.111023e+06            1.111023e+06    1.111023e+06
# mean             3.300936e-01           -1.204465e+01    7.148156e+00
# std              5.337786e+00            5.473204e+01    2.488432e+00
# min              7.300000e-02           -5.355000e+01    1.000000e+00
# 25%              1.730000e-01           -5.296000e+01    5.510000e+00
# 50%              1.890000e-01           -5.283000e+01    7.188000e+00
# 75%              2.070000e-01            6.683000e+01    8.710000e+00
# max              2.687000e+02            6.846000e+01    1.750000e+01
#
#        WS_ICEFREE_Std  BP_mbar_76m_Avg  AirTC_3m_Avg    RH_76m_Avg
# count    1.111023e+06     1.111023e+06  1.111023e+06  1.111023e+06
# mean     8.295196e-01     9.499480e+02  1.299019e+01  8.158775e+01
# std      4.152697e-01     6.787161e+00  7.809904e+00  2.361027e+01
# min      0.000000e+00     9.300000e+02 -1.292000e+01  3.533000e+01
# 25%      5.190000e-01     9.450000e+02  7.547000e+00  6.102000e+01
# 50%      7.810000e-01     9.500000e+02  1.308000e+01  8.150000e+01
# 75%      1.064000e+00     9.550000e+02  1.865000e+01  1.002000e+02
# max      3.804000e+00     9.710000e+02  3.194000e+01  1.277000e+02
#
# [8 rows x 77 columns]

# %%
#Computing air density. Converted mbar to Pacals and degrees C to Kelvin
df_MT['Air_density'] = df_MT['BP_mbar_76m_Avg']*100/(df_MT['AirTC_3m_Avg']+273.15)*287.05

df_MT.describe()
# Out:
#           StationId  CommunicationId   NeighbourId  NeighbourIdTwo  \
# count  1.111023e+06     1.111023e+06  1.111023e+06    1.111023e+06
# mean   4.404165e+01     2.309002e+06  4.403962e+01    4.468494e+01
# std    2.511075e+01     2.511075e+01  2.492885e+01    2.469343e+01
# min    1.000000e+00     2.308959e+06  2.000000e+00    1.000000e+00
# 25%    2.200000e+01     2.308980e+06  2.300000e+01    2.400000e+01
# 50%    4.400000e+01     2.309002e+06  4.300000e+01    4.400000e+01
# 75%    6.600000e+01     2.309024e+06  6.500000e+01    6.600000e+01
# max    8.700000e+01     2.309045e+06  8.600000e+01    8.700000e+01
#
#                XPos          YPos  wtc_ActPower_min  wtc_ActPower_max  \
# count  1.111023e+06  1.111023e+06      1.110941e+06      1.110941e+06
# mean   5.349489e+02  7.647548e+02      8.140967e+02      1.453176e+03
# std    3.398955e+02  4.244587e+02      7.543171e+02      8.236300e+02
# min    3.000000e+01  1.500000e+02     -5.100000e+02     -2.900000e+01
# 25%    2.600000e+02  4.500000e+02      1.560000e+02      7.110000e+02
# 50%    4.900000e+02  7.500000e+02      5.870000e+02      1.570000e+03
# 75%    8.350000e+02  1.050000e+03      1.399000e+03      2.324000e+03
# max    1.065000e+03  1.650000e+03      2.382000e+03      2.614000e+03
#
#        wtc_ActPower_mean  wtc_ActPower_stddev      ...       \
# count       1.110941e+06         1.110941e+06      ...
# mean        1.138954e+03         1.456796e+02      ...
# std         7.861914e+02         1.319418e+02      ...
# min        -4.383652e+01         0.000000e+00      ...
# 25%         4.273109e+02         4.366027e+01      ...
# 50%         1.069538e+03         1.034365e+02      ...
# 75%         1.865646e+03         2.149697e+02      ...
# max         2.426992e+03         1.181508e+03      ...
#
#        WindDir_76m_SD1_WVT  WindDir_Angle_3D_Avg.1  WindDir_Angle_3D_Std.1  \
# count         1.111023e+06            1.111023e+06            1.111023e+06
# mean          5.394040e+00            5.700405e+02            3.300936e-01
# std           1.040793e+01            2.700509e+01            5.337786e+00
# min           5.900000e-02            3.070000e+01            7.300000e-02
# 25%           8.220000e-01            5.709000e+02            1.730000e-01
# 50%           1.757000e+00            5.716000e+02            1.890000e-01
# 75%           5.322000e+00            5.719000e+02            2.070000e-01
# max           7.946000e+01            5.781000e+02            2.687000e+02
#
#        Elevation_angle_3D_Avg  WS_ICEFREE_Avg  WS_ICEFREE_Std  \
# count            1.111023e+06    1.111023e+06    1.111023e+06
# mean            -1.204465e+01    7.148156e+00    8.295196e-01
# std              5.473204e+01    2.488432e+00    4.152697e-01
# min             -5.355000e+01    1.000000e+00    0.000000e+00
# 25%             -5.296000e+01    5.510000e+00    5.190000e-01
# 50%             -5.283000e+01    7.188000e+00    7.810000e-01
# 75%              6.683000e+01    8.710000e+00    1.064000e+00
# max              6.846000e+01    1.750000e+01    3.804000e+00
#
#        BP_mbar_76m_Avg  AirTC_3m_Avg    RH_76m_Avg   Air_density
# count     1.111023e+06  1.111023e+06  1.111023e+06  1.111023e+06
# mean      9.499480e+02  1.299019e+01  8.158775e+01  9.537698e+04
# std       6.787161e+00  7.809904e+00  2.361027e+01  3.003143e+03
# min       9.300000e+02 -1.292000e+01  3.533000e+01  8.787725e+04
# 25%       9.450000e+02  7.547000e+00  6.102000e+01  9.324267e+04
# 50%       9.500000e+02  1.308000e+01  8.150000e+01  9.507902e+04
# 75%       9.550000e+02  1.865000e+01  1.002000e+02  9.725878e+04
# max       9.710000e+02  3.194000e+01  1.277000e+02  1.067765e+05
#
# [8 rows x 78 columns]
